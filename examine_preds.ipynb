# %%
import pandas as pd

# %%
preds = pd.read_json('predictions.json').sort_index()

# %%
preds.head(30)
# Out:
#     movie_id  rating           timestamp  user_id  prediction
# 0        148     NaN 2000-12-27 23:17:06       53    4.200000
# 1        148     NaN 2000-12-11 18:33:22     4169    3.297730
# 2        148     NaN 2001-05-05 01:07:36     5333    3.566935
# 3        148     NaN 2000-12-16 22:23:01     4387    3.130060
# 4        148     NaN 2000-08-22 01:20:08     3539    3.302363
# 5        148     NaN 2000-12-08 09:08:58      840    4.200000
# 6        148     NaN 2000-12-15 00:53:59      216    4.800000
# 7        148     NaN 2000-12-07 12:12:34      482    3.800000
# 8        148     NaN 2002-08-14 00:12:15      752    4.200000
# 9        148     NaN 2002-07-18 07:40:24      424    3.400000
# 10       148     NaN 2000-11-13 21:16:33     2456    3.323525
# 11       148     NaN 2000-09-28 12:41:30     3053    3.550480
# 12       463     NaN 2001-01-27 11:54:13      970    4.000000
# 13       463     NaN 2000-12-11 18:54:47     4169    2.890729
# ...
